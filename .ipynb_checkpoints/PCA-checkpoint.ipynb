# %% [markdown]
# ## Import and Normalize Data

# %%
# this notebook is very similar to the regression modelling notebook except PCA is added prior to modelling

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# Import Data
df2 = pd.read_csv('Data_grouped_by_date.csv', parse_dates=['date'], infer_datetime_format=True)
df2.drop(columns='date',inplace = True)

# Normalize and Log data
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler

# Initilize 
pt = PowerTransformer()
ss = StandardScaler()

#Power Transform -> Silica Feed, Silica Concentrate, Total Level
#Standard Scaler -> Everthing else
pt_data = df2[['% Silica Feed', '% Silica Concentrate']] #'total level']]
ss_data = df2.drop(columns=['% Silica Feed','% Silica Concentrate']) #'total level'])

#fit_transform data
df2_pt = pd.DataFrame(pt.fit_transform(pt_data), columns = pt_data.columns)
df2_ss = pd.DataFrame(ss.fit_transform(ss_data), columns = ss_data.columns)

#combine data - df3 become normalized df2 data
df3 = pd.concat([df2_pt,df2_ss], axis=1)

# %% [markdown]
# ## PCA - Plot Explanied Variance

# %%
# We have plotted the cumulative explanied Variance using PCA
# As can be seen from the graph 5 variables are able to explain 70% of the data

from sklearn.decomposition import PCA

pca = PCA()
pca.fit(df3)

exp_var_cumul = np.cumsum(pca.explained_variance_ratio_)

plt.plot(exp_var_cumul)
plt.title('Explained Variance',fontsize=15)
plt.xlabel('# of Dimensions')
plt.ylabel('Total Variance')
plt.show()

# %% [markdown]
# ## PCA = 5

# %%
#create list to hold model results
# we will start by testing PCA = 5, then PCA = 10 & 15

Iron_R2 = []
Iron_MAE = []
Iron_MSE = []

Silica_R2 = []
Silica_MAE = []
Silica_MSE = []

n_components = 5

# %% [markdown]
# ## Poly Reg Model

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression

#initialize and fit training dataset
model = make_pipeline(PolynomialFeatures(2),LinearRegression())
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
Polyreg_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.099
# MAE Score: 0.751
# MSE Score: 0.914
# Test R2 Score: 0.105

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

#initialize and fit training dataset
model = make_pipeline(PolynomialFeatures(2),LinearRegression())
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
Polyreg_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Optimized Model Iron Concentrate")
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Optimized Model Iron Concentrate
# Train R2 Score: 0.099
# MAE Score: 0.751
# MSE Score: 0.914
# Test R2 Score: 0.105

# %% [markdown]
# ## Random Forest ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import RandomForestRegressor

#initialize and fit training dataset
model = RandomForestRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RandomForest_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.89
# MAE Score: 0.673
# MSE Score: 0.75
# Test R2 Score: 0.266

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import RandomForestRegressor

#initialize and fit training dataset
model = RandomForestRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RandomForest_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.889
# MAE Score: 0.674
# MSE Score: 0.753
# Test R2 Score: 0.263

# %% [markdown]
# ## Gradient Boosting Regressor ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import GradientBoostingRegressor

#initialize and fit training dataset
model = GradientBoostingRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
GradientBoosting_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.297
# MAE Score: 0.724
# MSE Score: 0.867
# Test R2 Score: 0.152

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import GradientBoostingRegressor

#initialize and fit training dataset
model = GradientBoostingRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
GradientBoosting_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.29
# MAE Score: 0.725
# MSE Score: 0.867
# Test R2 Score: 0.152

# %% [markdown]
# ## XGBoost Regressor ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from xgboost import XGBRegressor

#initialize and fit training dataset
model = XGBRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
XGBoost_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.873
# MAE Score: 0.732
# MSE Score: 0.878
# Test R2 Score: 0.141

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from xgboost import XGBRegressor

#initialize and fit training dataset
model = XGBRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
XGBoost_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.879
# MAE Score: 0.714
# MSE Score: 0.855
# Test R2 Score: 0.164

# %% [markdown]
# ## SVR ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.svm import SVR

#initialize and fit training dataset
model = SVR()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
SVR_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.148
# MAE Score: 0.714
# MSE Score: 0.897
# Test R2 Score: 0.122

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.svm import SVR

#initialize and fit training dataset
model = SVR()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
SVR_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.148
# MAE Score: 0.714
# MSE Score: 0.897
# Test R2 Score: 0.122

# %% [markdown]
# ## Store PCA = 5 results

# %%
# create a results table 
Iron_df_5 = pd.DataFrame(
    {
        "Model": ['Polyreg_model','RandomForest_model','GradientBoosting_model','XGBoost_model', 'SVR_model'],
        "Iron_R2_5" : Iron_R2,
        "Iron_MAE_5" : Iron_MAE,
        "Iron_MSE_5" : Iron_MSE
    }

)


Silica_df_5 = pd.DataFrame(
    {
        "Model": ['Polyreg_model','RandomForest_model','GradientBoosting_model','XGBoost_model', 'SVR_model'],
        "Silica_R2_5" : Silica_R2,
        "Silica_MAE_5" : Silica_MAE,
        "Silica_MSE_5" : Silica_MSE
    }

)

# %% [markdown]
# ## PCA = 10

# %%
#create list to hold model results
# we will start by testing PCA = 5, then PCA = 10 & 15

Iron_R2 = []
Iron_MAE = []
Iron_MSE = []

Silica_R2 = []
Silica_MAE = []
Silica_MSE = []

n_components = 10

# %% [markdown]
# ## Poly Reg Model

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression

#initialize and fit training dataset
model = make_pipeline(PolynomialFeatures(2),LinearRegression())
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
Polyreg_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.197
# MAE Score: 0.717
# MSE Score: 0.831
# Test R2 Score: 0.187

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

#initialize and fit training dataset
model = make_pipeline(PolynomialFeatures(2),LinearRegression())
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
Polyreg_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Optimized Model Iron Concentrate")
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Optimized Model Iron Concentrate
# Train R2 Score: 0.197
# MAE Score: 0.717
# MSE Score: 0.831
# Test R2 Score: 0.187

# %% [markdown]
# ## Random Forest ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import RandomForestRegressor

#initialize and fit training dataset
model = RandomForestRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RandomForest_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.898
# MAE Score: 0.649
# MSE Score: 0.697
# Test R2 Score: 0.318

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import RandomForestRegressor

#initialize and fit training dataset
model = RandomForestRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RandomForest_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.9
# MAE Score: 0.646
# MSE Score: 0.688
# Test R2 Score: 0.327

# %% [markdown]
# ## Gradient Boosting Regressor ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import GradientBoostingRegressor

#initialize and fit training dataset
model = GradientBoostingRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
GradientBoosting_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.347
# MAE Score: 0.705
# MSE Score: 0.816
# Test R2 Score: 0.201

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import GradientBoostingRegressor

#initialize and fit training dataset
model = GradientBoostingRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
GradientBoosting_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.347
# MAE Score: 0.704
# MSE Score: 0.815
# Test R2 Score: 0.202

# %% [markdown]
# ## XGBoost Regressor ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from xgboost import XGBRegressor

#initialize and fit training dataset
model = XGBRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
XGBoost_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.93
# MAE Score: 0.691
# MSE Score: 0.795
# Test R2 Score: 0.222

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from xgboost import XGBRegressor

#initialize and fit training dataset
model = XGBRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
XGBoost_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.93
# MAE Score: 0.691
# MSE Score: 0.795
# Test R2 Score: 0.222

# %% [markdown]
# ## SVR ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.svm import SVR

#initialize and fit training dataset
model = SVR()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
SVR_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.298
# MAE Score: 0.663
# MSE Score: 0.765
# Test R2 Score: 0.251

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.svm import SVR

#initialize and fit training dataset
model = SVR()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
SVR_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.298
# MAE Score: 0.663
# MSE Score: 0.765
# Test R2 Score: 0.251

# %% [markdown]
# ## Store PCA = 10 results

# %%
# create a results table 
Iron_df_10 = pd.DataFrame(
    {
        "Iron_R2_10" : Iron_R2,
        "Iron_MAE_10" : Iron_MAE,
        "Iron_MSE_10" : Iron_MSE
    }

)


Silica_df_10 = pd.DataFrame(
    {
        "Silica_R2_10" : Silica_R2,
        "Silica_MAE_10" : Silica_MAE,
        "Silica_MSE_10" : Silica_MSE
    }

)

# %% [markdown]
# ## PCA = 15

# %%
#create list to hold model results
# we will start by testing PCA = 5, then PCA = 10 & 15

Iron_R2 = []
Iron_MAE = []
Iron_MSE = []

Silica_R2 = []
Silica_MAE = []
Silica_MSE = []

n_components = 15

# %% [markdown]
# ## Poly Reg Model

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression

#initialize and fit training dataset
model = make_pipeline(PolynomialFeatures(2),LinearRegression())
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
Polyreg_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.256
# MAE Score: 0.715
# MSE Score: 0.821
# Test R2 Score: 0.197

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

#initialize and fit training dataset
model = make_pipeline(PolynomialFeatures(2),LinearRegression())
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
Polyreg_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Optimized Model Iron Concentrate")
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Optimized Model Iron Concentrate
# Train R2 Score: 0.256
# MAE Score: 0.715
# MSE Score: 0.821
# Test R2 Score: 0.197

# %% [markdown]
# ## Random Forest ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import RandomForestRegressor

#initialize and fit training dataset
model = RandomForestRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RandomForest_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.904
# MAE Score: 0.65
# MSE Score: 0.705
# Test R2 Score: 0.311

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import RandomForestRegressor

#initialize and fit training dataset
model = RandomForestRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RandomForest_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.903
# MAE Score: 0.647
# MSE Score: 0.688
# Test R2 Score: 0.326

# %% [markdown]
# ## Gradient Boosting Regressor ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import GradientBoostingRegressor

#initialize and fit training dataset
model = GradientBoostingRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
GradientBoosting_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.403
# MAE Score: 0.702
# MSE Score: 0.786
# Test R2 Score: 0.23

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.ensemble import GradientBoostingRegressor

#initialize and fit training dataset
model = GradientBoostingRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
GradientBoosting_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.403
# MAE Score: 0.701
# MSE Score: 0.786
# Test R2 Score: 0.231

# %% [markdown]
# ## XGBoost Regressor ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from xgboost import XGBRegressor

#initialize and fit training dataset
model = XGBRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
XGBoost_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.955
# MAE Score: 0.686
# MSE Score: 0.784
# Test R2 Score: 0.233

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from xgboost import XGBRegressor

#initialize and fit training dataset
model = XGBRegressor()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
XGBoost_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.955
# MAE Score: 0.686
# MSE Score: 0.784
# Test R2 Score: 0.233

# %% [markdown]
# ## SVR ModeL

# %% [markdown]
# ### A) Predicting Iron Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.svm import SVR

#initialize and fit training dataset
model = SVR()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
SVR_model_R2_Iron = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores in list
Iron_R2.append(R2)
Iron_MAE.append(MAE)
Iron_MSE.append(MSE)
# Out:
# Train R2 Score: 0.366
# MAE Score: 0.649
# MSE Score: 0.743
# Test R2 Score: 0.273

# %% [markdown]
# ### B) Predicting Silica Concentrate

# %%
# create target variable
Y = df3['% Iron Concentrate']
X = df3.drop(columns=['% Iron Concentrate','% Silica Concentrate'])

# Apply PCA to train set
pca = PCA(n_components=n_components)
X = pca.fit_transform(X)

# split X and y into training and testing sets 
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test = model_selection.train_test_split(X,Y,train_size=0.75,test_size=0.25,random_state=123)

# import libraries
from sklearn.svm import SVR

#initialize and fit training dataset
model = SVR()
model.fit(X_train,y_train)

#make prediction 
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

MAE = mean_absolute_error(y_test,y_pred)
R2 = r2_score(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
SVR_model_R2_Silica = R2

#prints the model scores for your test dataset
print("Train R2 Score:", round(model.score(X_train,y_train),3))
print("MAE Score:", round(MAE,3))
print("MSE Score:", round(MSE,3))
print("Test R2 Score:", round(R2,3))

#make a graph for R2
graph = pd.DataFrame(
        {
            'actual':y_test,
            'predicted':y_pred
        }
)
sns.regplot(x='predicted',y='actual',data=graph,label='R2:'+ str(round(r2_score(y_test,y_pred),3)))
plt.legend(loc=0)
plt.show()

#append scores to list
Silica_R2.append(R2)
Silica_MAE.append(MAE)
Silica_MSE.append(MSE)
# Out:
# Train R2 Score: 0.366
# MAE Score: 0.649
# MSE Score: 0.743
# Test R2 Score: 0.273

# %% [markdown]
# ## Store PCA = 15 results

# %%
# create a results table 
Iron_df_15 = pd.DataFrame(
    {
        "Iron_R2_15" : Iron_R2,
        "Iron_MAE_15" : Iron_MAE,
        "Iron_MSE_15" : Iron_MSE
    }

)


Silica_df_15 = pd.DataFrame(
    {
        "Silica_R2_15" : Silica_R2,
        "Silica_MAE_15" : Silica_MAE,
        "Silica_MSE_15" : Silica_MSE
    }

)

# %% [markdown]
# ## Final Results

# %%
# create a results table 

Iron_df = pd.concat([Iron_df_5,Iron_df_10,Iron_df_15], axis=1)
Silica_df = pd.concat([Silica_df_5,Silica_df_10,Silica_df_15], axis=1)

print('% Iron Concentrate Results')
display(Iron_df)

print('% Silica Concentrate Results')
display(Silica_df)
# Out:
# % Iron Concentrate Results
#                     Model  Iron_R2_5  Iron_MAE_5  Iron_MSE_5  Iron_R2_10  \
# 0           Polyreg_model   0.105462    0.751227    0.914239    0.187142
# 1      RandomForest_model   0.266339    0.672790    0.749818    0.318386
# 2  GradientBoosting_model   0.151843    0.724206    0.866836    0.201421
# 3           XGBoost_model   0.140894    0.732099    0.878026    0.222099
# 4               SVR_model   0.121950    0.714287    0.897387    0.251005
#
#    Iron_MAE_10  Iron_MSE_10  Iron_R2_15  Iron_MAE_15  Iron_MSE_15
# 0     0.717061     0.830760    0.197060     0.715287     0.820623
# 1     0.648561     0.696625    0.310563     0.650049     0.704620
# 2     0.704558     0.816166    0.230458     0.701614     0.786489
# 3     0.690666     0.795032    0.232630     0.686403     0.784270
# 4     0.662856     0.765490    0.272709     0.648910     0.743308
# % Silica Concentrate Results
#                     Model  Silica_R2_5  Silica_MAE_5  Silica_MSE_5  \
# 0           Polyreg_model     0.105462      0.751227      0.914238
# 1      RandomForest_model     0.263297      0.674360      0.752928
# 2  GradientBoosting_model     0.152096      0.725169      0.866577
# 3           XGBoost_model     0.163502      0.714180      0.854920
# 4               SVR_model     0.121955      0.714289      0.897382
#
#    Silica_R2_10  Silica_MAE_10  Silica_MSE_10  Silica_R2_15  Silica_MAE_15  \
# 0      0.187142       0.717061       0.830760      0.197060       0.715287
# 1      0.327189       0.645662       0.687629      0.326482       0.646705
# 2      0.202086       0.703982       0.815487      0.231336       0.701210
# 3      0.222099       0.690666       0.795032      0.232630       0.686403
# 4      0.250996       0.662860       0.765500      0.272709       0.648910
#
#    Silica_MSE_15
# 0       0.820623
# 1       0.688350
# 2       0.785593
# 3       0.784270
# 4       0.743308
